# %% [markdown]
# # **Documentación del Proyecto - Librerías en Python: Jupyter, Pandas, Bokeh**
# ***
# # _**1. CONCEPTOS**_
# ## * **_Python:_**
# ### Básicamente, Python es un lenguaje de programación de alto nivel, interpretado y multipropósito. En los últimos años su utilización ha ido constantemente creciendo y en la actualidad es uno de los lenguajes de programación más empleados para el desarrollo de software.
# ### Entre las principales razones para elegir Python, son muhos los que argumentan que sus principales características lo convierten en un lenguaje muy productivo. Se trata de un lenguaje potente, flexible y con una sintaxis clara y concisa. Además, no requiere dedicar tiempo a su compilación debido a que es interpretado.
#
# ## * **_Jupyter Notebook:_**
# ### El Jupyter Notebook es una aplicación web de código abierto que le permite crear y compartir documentos que contengan códigos, ecuaciones, visualizaciones y textos narrativos en vivo. Los usos incluyen: limpieza y transformación de datos, simulación numérica, modelado estadístico, visualización de datos, aprendizaje automático y mucho más.
#
# ## * **_Bokeh:_**
# ### Bokeh es una biblioteca de visualización interactiva de Python que se dirige a navegadores web modernos para su presentación. Su objetivo es proporcionar una construcción elegante y concisa de gráficos novedosos al estilo de D3.js y ampliar esta capacidad con interactividad de alto rendimiento en conjuntos de datos de gran tamaño o de transmisión. Bokeh puede ayudar a cualquiera que desee crear trazados interactivos, cuadros de mando y aplicaciones de datos de manera rápida y fácil.
#
#
# ## * **_Pandas:_**
# ### Pandas es un paquete de Python que proporciona estructuras de datos similares a los dataframes de R.
# ### Pandas proporciona herramientas que permiten:
# ### 1. leer y escribir datos en diferentes formatos: CSV, Microsoft Excel, bases SQL y formato HDF5
# ### 2. seleccionar y filtrar de manera sencilla tablas de datos en función de posición, valor o etiquetas
# ### 3. fusionar y unir datos
# ### 4. transformar datos aplicando funciones tanto en global como por ventanas
# ### 5. manipulación de series temporales
# ### 6. hacer gráficas
#
#
# ### Python es open source, cualquiera puede contribuir a su desarrollo y divulgación. Además, no es necesario pagar ninguna licencia para distribuir software desarrollado con esté lenguaje. Hasta su intérprete se distribuye de forma gratuita para diferentes plataformas.
# ***
# # _**2. PASOS A SEGUIR**_
# ## Paso 1: hay que Descargar el Modulo "PIP3" si Python es de la Version 3 en adelante o Comando "PIP" si la Version es abajo de la 3. El comando se ingresa en el Modulo del Sistema de Windows "pip install matplotlib"
# ![Instalar PIP3](https://github.com/Jtaramon/f-algoritmos-tf-17/blob/master/Captura.PNG)
# ***
# ##NOTA: Si Pasas de la Version 2 de Python a la 3, Hay que asegurarse que esten Bien instaladas lo que es el SetupTools, PIP y Wheel y esto se hace con el comando "pip install -U pip setuptools wheel"
# ![](https://github.com/Jtaramon/f-algoritmos-tf-17/blob/master/Md.PNG)
# ***
# ## Paso 2: Instalar Librería Bokeh comando "pip install bokeh"
# ![](https://github.com/Jtaramon/f-algoritmos-tf-17/blob/master/Captura2.PNG)
# ***
# ## Paso 3: Verificar Version: En el simbolo de sistema entramos por medio de las variables de entorno a Python, ingresamos "Import bokeh" enter, despues "bokeh.__version__".
# ![](https://github.com/Jtaramon/f-algoritmos-tf-17/blob/master/Captura3_verifi.PNG)
# ***
# ## Paso 4: Instalar Librería Jupyter comando: "pip install jupyter"
# ![](https://github.com/Jtaramon/f-algoritmos-tf-17/blob/master/Captura4_install_Jupyter.PNG)
# ***
# ## Paso 5: Instalar Librería Pandas comando: "pip install pandas"
# ![](https://github.com/Jtaramon/f-algoritmos-tf-17/blob/master/Captura_pandas.PNG)
# ***
# ## Paso 6: Ejecutar el libro Jupyter comando: "jupyter notebook"
# ![](https://github.com/Jtaramon/f-algoritmos-tf-17/blob/master/notebook.PNG)
# ***
# ## Paso 7: Importamos PANDAS para poder leer el Archivo CSV.
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec1.PNG)
# ***
# ## Paso 8: Leemos el Archivo csv, Tambien lo vamos acomodando con comando, por ejemplo SEPS: que es por lo que esta separado, en este caso por Punto y Coma; encoding='latin1 que da a entender que el Idioma es el Latino
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec2.PNG)
# ***
# ## Paso 9: Limitamos la Columnas, pido que me Salga solo las INCIDENCIAS DE Quito, Guayaquil, Cuenca, Machala y Ambato
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec3.PNG)
# ***
# ## Paso 10: Verifico el Tipo de mi Tabla de Datos, y efectivamente es DataFrame de Pandas
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec5.PNG)
# ***
# ## Paso 11: Importo las LIBRERIAS de BOKEH que me van a ayudar a la Visualizacion de Datos, creo un objeto ciudades que obtiene las etiquetas que despues son ubicadas en el eje X, creamos el data que son los datos de cada ciduad, ColumnDataSource ayuda a dirigir la tabla con los datos
# ## En "p" creamos la figura, le damos en rango X y Y el Tamaño, el Titulo
# ## p.vbar Vamos dando Valores a las etiquetas que pusimos en el principio.
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec6.PNG)
# ## Show(p) Imprime la Grafica
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec7.PNG)
# ***
# ## Paso 12: Creamos otra figura que es Lineal, igualmente en P, creamos la figura con el Rango x y el Y le damos un tamaño de 700 y su respectivo Titulo
# ## p.line Les Asignamos sus Datos acerca de la Severidad de la Pobreza del Ecuador
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec8.PNG)
# ***
# ## Paso 13: Creamos un diagrama de puntos, en P creamos la figura con sus rangos de X y Y el tamaño de la cabecera, Titulo
# ## p.circle agregamos sus datos correspondientes, color, Tamaño
# ![](https://github.com/programacion-taw-utpl-001/trabajo-final-primer-bimestre-final-006/blob/master/Proyecto/Recursos/rec9.PNG)
#
# # _**3. BIBLIOGRAFIA**_
# ### [Pandas](https://pandas.pydata.org/)
# ### [Bokeh](https://bokeh.pydata.org/en/latest/docs/user_guide/quickstart.html#userguide-quickstart)
# ### [Jupyter Notebook](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Notebook%20Basics.html)

# %%
import pandas as pd

# %%
datos = pd.read_csv('Recursos/1.1.4.pobre_ciudades.csv', encoding='latin1',sep=';',parse_dates=['Año'], index_col='Año')
datos
# Out:
#          Período        Quito-1   Quito-2      Quito-3   Guayaquil-1  \
# Año
# -               -  Incidencia-1  Brecha-2  Severidad-3  Incidencia-1
# 2008        Marzo          10,5       3,3          1,8          22,1
# 2009        Marzo          11,2       3,7            2          24,3
# 2010        Marzo            13       4,3          2,3          20,8
# 2011        Marzo          10,3       3,3          1,8          19,2
# 2012        Marzo             9       3,3          1,6            11
# 2013        Marzo          10,9       3,5          1,6          12,8
# 2014        Marzo           8,9       2,8          1,4          11,7
# 2015        Marzo           7,9       2,6          1,3           7,7
# 2016        Marzo             8       2,6          1,3           8,7
# 2017        Marzo           7,4       2,4          1,2            11
# 2007       Junio           11,1       3,6          1,8          18,9
# 2008       Junio            8,5       2,3          0,9            11
# 2009       Junio           10,9       3,7          1,8          17,3
# 2010       Junio           13,8       4,4          2,2          21,8
# 2011       Junio              9       2,7          1,2          15,6
# 2012       Junio            7,9       2,5          1,2            10
# 2013       Junio            8,4       2,3          1,2          13,8
# 2014       Junio            7,3       2,2            1          12,6
# 2015       Junio            6,2       1,8          0,8           9,7
# 2016       Junio            7,9       2,2            1           8,5
# 2017       Junio            7,8       2,2            1          10,5
# 2007  Septiembre             10       3,2          1,6          18,6
# 2008  Septiembre            8,7       2,5            1          13,8
# 2009  Septiembre           13,8       4,4          2,2          18,5
# 2010  Septiembre           11,5         4          2,2          18,3
# 2011  Septiembre            9,6       3,2          1,6          11,1
# 2012  Septiembre            6,3       1,5          0,6          12,5
# 2013  Septiembre            9,8       3,2          1,6          13,2
# 2014  Septiembre            7,1       2,2          1,1          11,2
# 2015  Septiembre            5,6       1,5          0,7           9,6
# 2016  Septiembre            9,4       3,3          1,7           9,7
# 2007    Diciembre          10,1       3,4          1,6          22,5
# 2008    Diciembre            10       3,2          1,5          13,1
# 2009    Diciembre          12,1       4,4          2,3          20,1
# 2010    Diciembre          10,5       3,8          1,9          20,1
# 2011    Diciembre           9,1       2,6          1,2           9,1
# 2012    Diciembre             8       2,6          1,4           7,2
# 2013    Diciembre           6,1       2,3          1,2          16,7
# 2014    Diciembre           7,5       2,1            1          12,7
# 2015    Diciembre           8,7       2,9          1,5          11,7
# 2016    Diciembre          10,2       3,7          2,1          12,5
#
#      Guayaquil-2  Guayaquil-3      Cuenca-1  Cuenca-2     Cuenca-3  \
# Año
# -       Brecha-2  Severidad-3  Incidencia-1  Brecha-2  Severidad-3
# 2008         6,4          2,9          11,7       3,7          1,9
# 2009         7,5          3,3          10,9       3,3          1,5
# 2010         5,8          2,4          13,8       3,8          1,6
# 2011           5            2          12,4       4,1          2,2
# 2012         2,8            1           9,7       2,9          1,3
# 2013         3,6          1,6           9,2       2,5            1
# 2014         3,1          1,2           4,7       1,7          0,9
# 2015         1,8          0,7           5,3       1,2          0,5
# 2016         2,5            1           7,8       2,6          1,2
# 2017         2,7          1,1           7,9       2,9          1,5
# 2007         3,4          3,1          12,8       4,7          2,5
# 2008         5,4          2,3           7,9       2,8          1,4
# 2009           5          2,2          11,2       3,4          1,5
# 2010         6,9          3,1          10,7       3,6          1,8
# 2011           4          1,6          11,8       3,2          1,5
# 2012         2,3          0,8           7,1       1,9          0,7
# 2013         3,7          1,6             6         2          0,9
# 2014         2,9          1,1           5,9       1,3          0,5
# 2015         2,3          0,8           5,6       1,3          0,5
# 2016         2,2          0,9           7,6         2          0,7
# 2017         2,5            1           7,8       2,1          0,9
# 2007         5,4          2,3          13,2       4,2          1,9
# 2008         4,3          1,9          11,1         4          2,1
# 2009         4,9          1,9          11,2       3,9          1,9
# 2010         4,6          1,7           9,4       2,5          1,1
# 2011         2,6            1             8       2,4            1
# 2012         3,9          1,9           7,7       2,1          0,8
# 2013         3,5          1,3           4,2       0,9          0,3
# 2014         2,6          1,1             5       1,5          0,7
# 2015         2,4            1           3,7       0,9          0,4
# 2016         2,1          0,8           9,7       3,5          1,6
# 2007         7,2          3,5          10,1       3,2          1,5
# 2008         3,6          1,4           8,1       2,4            1
# 2009         5,6          2,3          11,4         4          2,1
# 2010         5,1          1,9           9,7       2,8          1,2
# 2011         2,5          1,1           5,2       1,4          0,6
# 2012         1,8          0,7          10,1       2,3          0,9
# 2013           4          1,6             5       1,3          0,5
# 2014         3,2          1,2           7,8       2,5          1,2
# 2015         2,5            1           4,5         1          0,4
# 2016         3,5          1,5           7,5       2,1          0,9
#
#          Machala-1 Machala-2    Machala-3      Ambato-1  Ambato-2     Ambato-3
# Año
# -     Incidencia-1  Brecha-2  Severidad-3  Incidencia-1  Brecha-2  Severidad-3
# 2008          20,8       6,4          2,8          21,2       6,4          3,1
# 2009          20,8       6,3          2,9          17,6       5,8            3
# 2010          15,5       4,2          1,8          11,6       3,5          1,5
# 2011          14,8       4,1          1,6          10,6       2,7            1
# 2012           9,5       1,9          0,6             8         2          0,8
# 2013            12       2,5          0,8          10,5       3,7            2
# 2014          13,7       3,8          1,5          12,8       3,2          1,3
# 2015          15,1       4,2          1,8           8,4       2,9          1,2
# 2016          13,8       3,9          1,8           7,8       2,5          1,2
# 2017          16,8       4,5            2           9,7       3,1          1,6
# 2007          22,8       7,5          3,8          14,2       4,6          2,3
# 2008          19,6       4,7          1,9          14,8       4,8          2,2
# 2009          20,1       5,8          2,5          13,3       3,7          1,5
# 2010          17,3       6,4          3,1          13,6       4,1          1,9
# 2011          11,8       3,7          1,6          12,8       3,4          1,6
# 2012          10,4       2,1          0,7          10,9       2,8          1,2
# 2013            12       3,7          1,7          10,5       3,7          1,8
# 2014          14,2       3,8          1,5           7,9       2,5          1,2
# 2015           9,9       2,6          1,1           7,9       2,3            1
# 2016          10,1       2,5            1           9,8       3,4          1,6
# 2017          14,4       3,6          1,3          10,2       3,6          1,8
# 2007          22,8       7,5          3,6          15,1       4,6            2
# 2008          17,8       4,2          1,5          19,7       5,7          2,6
# 2009          19,5         6          2,6          14,4       4,2          1,8
# 2010          17,3       5,4          2,3          14,6         4          1,9
# 2011          11,8       2,9            1           8,9       2,6          1,1
# 2012          10,4       1,9          0,6           5,8         2          0,9
# 2013            12       2,9          1,2          10,5       3,7            2
# 2014          12,9       3,1          1,3           8,5       2,8          1,4
# 2015          11,1       2,9          1,2           8,6       2,4            1
# 2016            15       3,8          1,4          12,6       4,2          2,1
# 2007          26,2       8,7            4          17,8       6,2          3,1
# 2008          17,7         5            2          13,6       3,3          1,4
# 2009            16       4,6            2          17,1       5,1          2,3
# 2010            22       6,9          3,1          14,9       4,3          1,9
# 2011            12       3,2          1,3           9,8       2,8          1,1
# 2012           9,5       1,8          0,5             8       2,1          0,9
# 2013          12,3         3          1,2           7,4         2          0,9
# 2014          11,9       3,4          1,5           7,3       2,6          1,3
# 2015           9,6       2,9          1,3             8       2,1          0,9
# 2016          11,6         3          1,3          12,3       4,3          2,2

# %%
datos[['Quito-1','Guayaquil-1','Cuenca-1','Machala-1','Ambato-1']]
# Out:
#            Quito-1   Guayaquil-1      Cuenca-1     Machala-1      Ambato-1
# Año
# -     Incidencia-1  Incidencia-1  Incidencia-1  Incidencia-1  Incidencia-1
# 2008          10,5          22,1          11,7          20,8          21,2
# 2009          11,2          24,3          10,9          20,8          17,6
# 2010            13          20,8          13,8          15,5          11,6
# 2011          10,3          19,2          12,4          14,8          10,6
# 2012             9            11           9,7           9,5             8
# 2013          10,9          12,8           9,2            12          10,5
# 2014           8,9          11,7           4,7          13,7          12,8
# 2015           7,9           7,7           5,3          15,1           8,4
# 2016             8           8,7           7,8          13,8           7,8
# 2017           7,4            11           7,9          16,8           9,7
# 2007          11,1          18,9          12,8          22,8          14,2
# 2008           8,5            11           7,9          19,6          14,8
# 2009          10,9          17,3          11,2          20,1          13,3
# 2010          13,8          21,8          10,7          17,3          13,6
# 2011             9          15,6          11,8          11,8          12,8
# 2012           7,9            10           7,1          10,4          10,9
# 2013           8,4          13,8             6            12          10,5
# 2014           7,3          12,6           5,9          14,2           7,9
# 2015           6,2           9,7           5,6           9,9           7,9
# 2016           7,9           8,5           7,6          10,1           9,8
# 2017           7,8          10,5           7,8          14,4          10,2
# 2007            10          18,6          13,2          22,8          15,1
# 2008           8,7          13,8          11,1          17,8          19,7
# 2009          13,8          18,5          11,2          19,5          14,4
# 2010          11,5          18,3           9,4          17,3          14,6
# 2011           9,6          11,1             8          11,8           8,9
# 2012           6,3          12,5           7,7          10,4           5,8
# 2013           9,8          13,2           4,2            12          10,5
# 2014           7,1          11,2             5          12,9           8,5
# 2015           5,6           9,6           3,7          11,1           8,6
# 2016           9,4           9,7           9,7            15          12,6
# 2007          10,1          22,5          10,1          26,2          17,8
# 2008            10          13,1           8,1          17,7          13,6
# 2009          12,1          20,1          11,4            16          17,1
# 2010          10,5          20,1           9,7            22          14,9
# 2011           9,1           9,1           5,2            12           9,8
# 2012             8           7,2          10,1           9,5             8
# 2013           6,1          16,7             5          12,3           7,4
# 2014           7,5          12,7           7,8          11,9           7,3
# 2015           8,7          11,7           4,5           9,6             8
# 2016          10,2          12,5           7,5          11,6          12,3

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge
from bokeh.core.properties import value
output_notebook()

ciudadess = ['Quito','Guayaquil','Cuenca','Machala','Ambato']



data = {'ciudades' : ciudadess,
       'Quito-1' : [97.1,0,0,0,0],
       'Guayaquil-1' : [149.3,0,0,0,0],
       'Cuenca-1': [93.4,0,0,0,0],
       'Machala-1' : [152.8,0,0,0,0],
       'Ambato-1' : [118.2,0,0,0,0]}

source = ColumnDataSource(data=data)

p = figure(x_range = ciudadess, y_range = (0,200),plot_height=350,title="Pobreza Ecuador - INCIDENCIA - 2008/2017")


p.vbar(x=dodge('ciudades', 0 ,range = p.x_range),top='Quito-1',width=0.20,source=source, color="blue",legend=value("Q"))

p.vbar(x=dodge('ciudades', 1, range = p.x_range),top='Guayaquil-1',width=0.2,source=source, color="red",legend=value("G"))

p.vbar(x=dodge('ciudades', 2, range = p.x_range),top='Cuenca-1',width=0.2,source=source, color="green",legend=value("C"))

p.vbar(x=dodge('ciudades', 3, range = p.x_range),top='Machala-1',width=0.2,source=source, color="yellow",legend=value("M"))

p.vbar(x=dodge('ciudades', 4, range = p.x_range),top='Ambato-1',width=0.2,source=source, color="black",legend=value("A"))



p.x_range.range_padding =0
p.xgrid.grid_line_color = None
p.legend.location = "top_right"
p.legend.orientation = "horizontal"

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36632726-2945-4d4b-b990-b33db2c941e4">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="fbe03d61-3e0c-4cf1-ad66-9fd57b078401"></div>
# </div>

# %%
datos[['Quito-3','Guayaquil-3','Cuenca-3','Machala-3','Ambato-3']]
# Out:
#           Quito-3  Guayaquil-3     Cuenca-3    Machala-3     Ambato-3
# Año
# -     Severidad-3  Severidad-3  Severidad-3  Severidad-3  Severidad-3
# 2008          1,8          2,9          1,9          2,8          3,1
# 2009            2          3,3          1,5          2,9            3
# 2010          2,3          2,4          1,6          1,8          1,5
# 2011          1,8            2          2,2          1,6            1
# 2012          1,6            1          1,3          0,6          0,8
# 2013          1,6          1,6            1          0,8            2
# 2014          1,4          1,2          0,9          1,5          1,3
# 2015          1,3          0,7          0,5          1,8          1,2
# 2016          1,3            1          1,2          1,8          1,2
# 2017          1,2          1,1          1,5            2          1,6
# 2007          1,8          3,1          2,5          3,8          2,3
# 2008          0,9          2,3          1,4          1,9          2,2
# 2009          1,8          2,2          1,5          2,5          1,5
# 2010          2,2          3,1          1,8          3,1          1,9
# 2011          1,2          1,6          1,5          1,6          1,6
# 2012          1,2          0,8          0,7          0,7          1,2
# 2013          1,2          1,6          0,9          1,7          1,8
# 2014            1          1,1          0,5          1,5          1,2
# 2015          0,8          0,8          0,5          1,1            1
# 2016            1          0,9          0,7            1          1,6
# 2017            1            1          0,9          1,3          1,8
# 2007          1,6          2,3          1,9          3,6            2
# 2008            1          1,9          2,1          1,5          2,6
# 2009          2,2          1,9          1,9          2,6          1,8
# 2010          2,2          1,7          1,1          2,3          1,9
# 2011          1,6            1            1            1          1,1
# 2012          0,6          1,9          0,8          0,6          0,9
# 2013          1,6          1,3          0,3          1,2            2
# 2014          1,1          1,1          0,7          1,3          1,4
# 2015          0,7            1          0,4          1,2            1
# 2016          1,7          0,8          1,6          1,4          2,1
# 2007          1,6          3,5          1,5            4          3,1
# 2008          1,5          1,4            1            2          1,4
# 2009          2,3          2,3          2,1            2          2,3
# 2010          1,9          1,9          1,2          3,1          1,9
# 2011          1,2          1,1          0,6          1,3          1,1
# 2012          1,4          0,7          0,9          0,5          0,9
# 2013          1,2          1,6          0,5          1,2          0,9
# 2014            1          1,2          1,2          1,5          1,3
# 2015          1,5            1          0,4          1,3          0,9
# 2016          2,1          1,5          0,9          1,3          2,2

# %%
p = figure(x_range=ciudadess, y_range = (0,100),plot_width=700, plot_height=300,title="Pobreza Ecuador - SEVERIDAD - 2008/2017",toolbar_location = None, tools="")

p.line(['Quito', 'Guayaquil', 'Cuenca', 'Machala', 'Ambato'], [16.3,17.2,13.6,17.6,16.7] )

p.x_range.range_padding =0
p.xgrid.grid_line_color = None

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="132b855d-d2e9-465c-ae10-05a92d332e46"></div>
# </div>

# %%
datos[['Quito-2','Guayaquil-2','Cuenca-2','Machala-2','Ambato-2']]
# Out:
#        Quito-2 Guayaquil-2  Cuenca-2 Machala-2  Ambato-2
# Año
# -     Brecha-2    Brecha-2  Brecha-2  Brecha-2  Brecha-2
# 2008       3,3         6,4       3,7       6,4       6,4
# 2009       3,7         7,5       3,3       6,3       5,8
# 2010       4,3         5,8       3,8       4,2       3,5
# 2011       3,3           5       4,1       4,1       2,7
# 2012       3,3         2,8       2,9       1,9         2
# 2013       3,5         3,6       2,5       2,5       3,7
# 2014       2,8         3,1       1,7       3,8       3,2
# 2015       2,6         1,8       1,2       4,2       2,9
# 2016       2,6         2,5       2,6       3,9       2,5
# 2017       2,4         2,7       2,9       4,5       3,1
# 2007       3,6         3,4       4,7       7,5       4,6
# 2008       2,3         5,4       2,8       4,7       4,8
# 2009       3,7           5       3,4       5,8       3,7
# 2010       4,4         6,9       3,6       6,4       4,1
# 2011       2,7           4       3,2       3,7       3,4
# 2012       2,5         2,3       1,9       2,1       2,8
# 2013       2,3         3,7         2       3,7       3,7
# 2014       2,2         2,9       1,3       3,8       2,5
# 2015       1,8         2,3       1,3       2,6       2,3
# 2016       2,2         2,2         2       2,5       3,4
# 2017       2,2         2,5       2,1       3,6       3,6
# 2007       3,2         5,4       4,2       7,5       4,6
# 2008       2,5         4,3         4       4,2       5,7
# 2009       4,4         4,9       3,9         6       4,2
# 2010         4         4,6       2,5       5,4         4
# 2011       3,2         2,6       2,4       2,9       2,6
# 2012       1,5         3,9       2,1       1,9         2
# 2013       3,2         3,5       0,9       2,9       3,7
# 2014       2,2         2,6       1,5       3,1       2,8
# 2015       1,5         2,4       0,9       2,9       2,4
# 2016       3,3         2,1       3,5       3,8       4,2
# 2007       3,4         7,2       3,2       8,7       6,2
# 2008       3,2         3,6       2,4         5       3,3
# 2009       4,4         5,6         4       4,6       5,1
# 2010       3,8         5,1       2,8       6,9       4,3
# 2011       2,6         2,5       1,4       3,2       2,8
# 2012       2,6         1,8       2,3       1,8       2,1
# 2013       2,3           4       1,3         3         2
# 2014       2,1         3,2       2,5       3,4       2,6
# 2015       2,9         2,5         1       2,9       2,1
# 2016       3,7         3,5       2,1         3       4,3

# %%
p = figure(x_range=ciudadess, y_range = (0,60),plot_width=700, plot_height=300,title="Pobreza Ecuador - SEVERIDAD - 2008/2017",toolbar_location = None, tools="")

# add a line renderer
p.circle(['Quito', 'Guayaquil', 'Cuenca', 'Machala', 'Ambato'], [49.8,41.2,28.7,41.8,35.8],size=20, color=['red','black','yellow','green','blue'],
         alpha=0.5)

p.x_range.range_padding =0
p.xgrid.grid_line_color = None
p.legend.location = "top_right"
p.legend.orientation = "horizontal"
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="162cd742-2116-442a-9fcc-51252b37ed5a"></div>
# </div>
